# %%
# !pip install aspose-words
# Out:
# ...
#    ---------------------------------------- 0.0/67.9 MB ? eta -:--:--
#    ---------------------------------------- 0.8/67.9 MB 6.7 MB/s eta 0:00:10
#     --------------------------------------- 1.6/67.9 MB 4.4 MB/s eta 0:00:16
#    - -------------------------------------- 2.6/67.9 MB 4.6 MB/s eta 0:00:15
#    -- ------------------------------------- 3.7/67.9 MB 4.7 MB/s eta 0:00:14
#    -- ------------------------------------- 4.5/67.9 MB 4.5 MB/s eta 0:00:15
#    -- ------------------------------------- 5.0/67.9 MB 4.1 MB/s eta 0:00:16
#    --- ------------------------------------ 5.5/67.9 MB 4.0 MB/s eta 0:00:16
#    --- ------------------------------------ 6.6/67.9 MB 3.9 MB/s eta 0:00:16
#    ---- ----------------------------------- 7.1/67.9 MB 3.9 MB/s eta 0:00:16
#    ---- ----------------------------------- 7.9/67.9 MB 3.8 MB/s eta 0:00:16
#    ---- ----------------------------------- 8.4/67.9 MB 3.8 MB/s eta 0:00:16
# ...

# %%
import aspose.words as aw

# %%
doc = aw.Document("Pdffiles\Split_Bihar_1-43.pdf")
doc.save("markdown.md")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\rahul\AppData\Local\Temp\ipykernel_68692\4162395574.py:1: SyntaxWarning: invalid escape sequence '\S'
#   doc = aw.Document("Pdffiles\Split_Bihar_1-43.pdf")
